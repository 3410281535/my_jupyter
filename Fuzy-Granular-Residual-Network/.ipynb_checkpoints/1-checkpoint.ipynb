# %% [markdown]
# **信息系统** $\ U\ =\  (\ X\ ,\ C\ ,\ D\ )\ $ , **样本集**$\ X\ =\ ${$\ x_1\ ,\ \ x_2\ ,\ …\ ,\ x_n\ $}  ,  样本对应的**特征集**$\ C\ =\ ${$\ c_1\ ,\ c_2\ ,\ …\ ,\ c_n\ $}  ,  $\ D$ : 样本对应的**决策集**
# <BR>
# 从$\ X\ $中随机选取**参考样本集**$\ P\ =\ ${$\ p_1\ ,\ \ p_2\ ,\ …\ ,\ p_n\ $}$\ \subseteq\ X\ $
# <BR>
# 对于给定的样本集中的样本$\ x\ \in\ X\ $, 有对应特征$\ c\ \in\ C$, 样本$\ x\ $在特征$\ c\ $上**归一化的值**用$\ v\ (\ x\ ,\ c\ )\ \in\ [\ 0\ ,\ 1\ ]\ $表示
# <BR>
# 样本$\ x\ $和参考样本$\ p\ $在特征$\ c\ $上的**相似度**用$\ S_c(\ x\ ,\ p\ )\ =\ 1\ -\ |\ v\ (\ x\ ,\ c\ )\ -\ v\ (\ p\ ,\ c\ )\ |\ $表示
# <BR>
# 把 样本$\ x\ $ 和 参考样本集$\ P\ =\ ${$\ p_1\ ,\ \ p_2\ ,\ …\ ,\ p_n\ $} 在 任意特征$\ c\ \in\ C\ $上模糊造粒
# <BR>
# 样本$\ x\ $在 特征$\ c\ $上的 **模糊粒** 为 : $\ g_c(\ x\ )\ =\ \{\ {g_c(\ x\ )}_j\}^k_{j=1}\ =\ \{\ r_j\ \}^k_{j=1}\ =\ \{\ r_1\ ,\ r_2\ ,\ …\ ,\ r_k\ \}$
# <BR>
# $\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad其中,\ r_j\ =\ S_c(\ x\ ,\ p_j\ )\ =\ 1\ -\ |\ v\ (\ x\ ,\ c\ )\ -\ v\ (\ p_j\ ,\ c\ )\ |\ $
# <BR>
# $g_c(\ x\ )_j是模糊粒\ g_c(\ x\ )的第\ j\ 个模糊$**粒核**
# <BR>
# 对于任意**特征子集**$\ B\ =\ \{\ b_1\ ,\ b_2\ ,\ …\ ,\ b_m\ \}\ \subseteq\ C\ ,\ x\ $在特征子集B上的**模糊粒向量**为 : $G(\ x\ )\ =\ \{\ \ g_{b1}(\ x\ )\ ,\ g_{b2}(\ x\ )\ ,\ …\ ,\ g_{bm}(\ x\ )\ \}^T$
# <BR>
# <u>此处原文有明显错误</u>
# <BR>
# <img src="./错误.png" alt="错误" width="600"/>
# <BR>
# $g_{bm}(\ x\ )是样本\ x\ 在特征\ b_m\ 上的模糊粒$
# <BR><BR>
# **模糊粒向量**由模糊粒组成
# <BR>
# **模糊粒向量**$\ G(\ x\ )\ =\
# \left[
# \begin{matrix}
# g_{b1}(\ x\ )\\
# g_{b2}(\ x\ )\\
# …\\
# g_{bm}(\ x\ )
# \end{matrix}
# \right]
# \ =\
# \left[
# \begin{matrix}
# g_1(\ x\ )_1 & g_1(\ x\ )_2 & … & g_1(\ x\ )_k\\
# g_2(\ x\ )_1 & g_2(\ x\ )_2 & … & g_2(\ x\ )_k\\
# … & … & … & …\\
# g_m(\ x\ )_1 & g_m(\ x\ )_2 & … & g_m(\ x\ )_k\\
# \end{matrix}
# \right]
# \ =\
# \left[
# \begin{matrix}
# r_{11} & r_{12} & … & r_{1k}\\
# r_{21} & r_{22} & … & r_{2k}\\
# … & … & … & …\\
# r_{m1} & r_{m2} & … & r_{mk}\\
# \end{matrix}
# \right]
# $
# <BR>
# 模糊粒的 **四则运算** :
# <BR>
# $g_a(\ x\ )\ +\ g_b(\ x\ )\ =\ \{\ g_a(\ x\ )_j\ +\ g_b(\ x\ )_j\ \}^k_{j=1}$
# <BR>
# $\quad\quad=\ \{\ g_a(\ x\ )_1\ +\ g_b(\ x\ )_1\ ,\ g_a(\ x\ )_2\ +\ g_b(\ x\ )_2\ ,\ …\ ,\ g_a(\ x\ )_k\ +\ g_b(\ x\ )_k\ \}$
# <BR>
# $g_a(\ x\ )\ -\ g_b(\ x\ )\ =\ \{\ g_a(\ x\ )_j\ -\ g_b(\ x\ )_j\ \}^k_{j=1}$
# <BR>
# $\quad\quad=\ \{\ g_a(\ x\ )_1\ -\ g_b(\ x\ )_1\ ,\ g_a(\ x\ )_2\ -\ g_b(\ x\ )_2\ ,\ …\ ,\ g_a(\ x\ )_k\ -\ g_b(\ x\ )_k\ \}$
# <BR>
# $g_a(\ x\ )\ *\ g_b(\ x\ )\ =\ \{\ g_a(\ x\ )_j\ *\ g_b(\ x\ )_j\ \}^k_{j=1}$
# <BR>
# $\quad\quad=\ \{\ g_a(\ x\ )_1\ *\ g_b(\ x\ )_1\ ,\ g_a(\ x\ )_2\ *\ g_b(\ x\ )_2\ ,\ …\ ,\ g_a(\ x\ )_k\ *\ g_b(\ x\ )_k\ \}$
# <BR>
# $g_a(\ x\ )\ /\ g_b(\ x\ )\ =\ \{\ g_a(\ x\ )_j\ /\ g_b(\ x\ )_j\ \}^k_{j=1}$
# <BR>
# $\quad\quad=\ \{\ g_a(\ x\ )_1\ /\ g_b(\ x\ )_1\ ,\ g_a(\ x\ )_2\ /\ g_b(\ x\ )_2\ ,\ …\ ,\ g_a(\ x\ )_k\ /\ g_b(\ x\ )_k\ \}$
# <BR>
# 同一样本集内的不同样本$\ x\ ,\ y\ $也可以， 将上述式子第二项的 x 改为 y 即可
# <BR><BR>
# 两模糊粒向量 $G(\ x\ )\ =\ \{\ \ g_{1}(\ x\ )\ ,\ g_{2}(\ x\ )\ ,\ …\ ,\ g_{m}(\ x\ )\ \}^T\ ,\ G(\ y\ )\ =\ \{\ \ g_{1}(\ y\ )\ ,\ g_{2}(\ y\ )\ ,\ …\ ,\ g_{m}(\ y\ )\ \}^T\ $点积 :
# <BR><BR>
# $G(\ x\ )\ ·\ G(\ y\ )\ =\ g_1(\ x\ )\ *\ g_1(\ y\ )\ +\ g_2(\ x\ )\ *\ g_2(\ y\ )\ +\ …\ +\ g_m(\ x\ )\ *\ g_m(\ y\ )$
# <BR>
# 为一 **模糊粒**
# <BR><BR>
# **模糊粒权重向量** $\ W\ =\ \{\ w_1\ ,\ w_2\ ,\ …\ ,\ w_m\ ,\ b\ \}$
# <BR>
# 和 **模糊粒向量** 的**点积** :
# <BR>
# $W\ ·\ G(\ x\ )\ =\ w_1\ *\ g_1(\ x\ )\ +\ w_2\ *\ g_2(\ x\ )\ +\ …\ +\ w_m\ *\ g_m(\ x\ )\ +\ b$
# <BR>
# **模糊粒函数** $\ f(\ g(\ x\ )\ )\ =\ f\left(\ \{\ r_j\ \}^k_{j=1}\ \right)\ =\ \left\{\ f(\ r_1\ )\ ,\ f(\ r_2\ )\ ,\ …\ ,\ f(\ r_k\ )\ \right\} $
# <BR>
# 模糊粒$\ \{\ r_j\ \}^k_{j=1}\ $的 **质量**$\ Quality(\ g(\ x\ )\ )\ =\ \overset{k}{\underset{j=1}{\sum}}\ r_j\ $
# <BR><BR>
# 模糊粒向量的**p-范数** :
# <BR>
# $||\ G\ ||_p\ =\ (\ \overset{m}{\underset{i=1}{\sum}}\ {g_i}^p\ )^{\frac{1}{p}}$

# %% [markdown]
# 对于 **激活函数** ，输入为一个粒 , 输出也为一个粒 : ( 设模糊粒 $\ g(\ x\ )\ =\ \{\ r_j\ \}^k_{j=1}\ $)
# <BR>
# $f(\ g(\ x\ )\ )\ =\ \{\ f(\ r_j\ )\ \}^k_{j=1}$
# <BR>
# 求导同理，结果为粒 :
# <BR>
# $f^{'}(\ g(\ x\ )\ )\ =\ \{\ f^{'}(\ r_j\ )\ \}^k_{j=1}$
# <BR><BR>
# **粒卷积函数 :**
# <BR>
# 模糊粒向量 $G(\ x\ )\ =\ \{\ \ g_{1}(\ x\ )\ ,\ g_{2}(\ x\ )\ ,\ …\ ,\ g_{m}(\ x\ )\ \}\ $ , **卷积核** $K\ =\ \{\ \ k_{1}\ ,\ k_{2}\ ,\ …\ ,\ k_{n}\ \}\ $
# <BR><BR>
# **粒向量卷积** $S(\ G\ ,\ k\ )\ =\ (\ G\ ·\ K\ )[\ m\ ]\ =\ \underset{n}{\sum}G[m\ +\ n]\ ·\ K[\ n\ ]$
# <BR>$\quad\quad\quad\quad$--输出粒向量$\ S\ $
# <BR><BR>
# **损失函数**$\ L(\ G\ ,\ D\ )\ =\ \frac{1}{l}{||\ G\ -\ D\ ||}_1\ =\ \frac{1}{l}\overset{l}{\underset{i=1}{\sum}}|\ g_i\ -\ d_i\ |$ (绝对值损失函数) ,
# <BR>
# $\quad\quad\quad\quad\quad\quad\quad$or$\ =\ \frac{1}{l}{||\ G\ -\ D\ ||}^2_2\ $ (平方损失函数) ,
# <BR>
# $\quad\quad\quad\quad\quad\quad\quad$or$\ =\ -\ log(\ P\ )\ ·\ D\ =\ \overset{l}{\underset{i=1}{\sum}}log(\ p_i\ )\ *\ d_i\ $ (交叉熵损失函数, $\ p_i\ $为$\ softmax\ $后概率) ,
# <BR><BR>
# **误差粒向量**$\ E\ =\ \frac{\partial{L}}{\partial{S}}$
# <BR><BR>
# 对$\ K\ $进行求导以修正$\ K\ $值 :
# $\frac{\partial{L}}{\partial{K}}\ =\ \underset{n}{\sum}E\ ·\ G[\ m\ +\ n\ ]$

# %% [markdown]
# **粒残差网络算法**
# <BR>
# **输入** : 训练集$\ U\ =\ (\ X\ ,\ Y\ )\ ,\ x_i\ 为\ m\ 维特征向量\ ,\ x_i\ \in\ X\ \subseteq\ R^m\ ,\ y_i\ 为\ l\ 维标志向量\ ,\ y_i\ \in\ Y\ \subseteq\ R^l\ ,\ 意味着有\ l\ 个类别$
# <BR>
# **输出** : **粒权矩阵W**和**粒度阈值b**
# 1. 随机选取样本作为参考样本集$\ S\ =\ P_1\ ,\ P_2\ ,\ …\ ,\ P_k$
# 2. 训练集$\ p\ $在参考集$\ P\ $下模糊造粒$\ GT = \left\{ \left( G(x_1), G(y_1) \right)\ ,\ \left( G(x_2), G(y_2) \right)\ ,\ \dots\ ,\ \left( G(x_n), G(y_n) \right)\  \right\}\ ,\ $模糊粒特征向量$\ G(\ x_i\ )\ =\ \left\{ g_1(\ x_i)\ ,\ g_2(\ x_i\ )\ ,\ \dots\ ,\ g_m(\ x_i\ ) \right\}\ ,\ $模糊粒标签向量$\ G(\ y_i\ )\ =\ \left\{ g_1(\ y_i)\ ,\ g_2(\ y_i\ )\ ,\ \dots\ ,\ g_l(\ y_i\ ) \right\}\ $
# 3. 构建多层粒神经网络并随机初始化粒权重
# 4. 对$\ x\ \in\ X\ ,\ $输入特征模糊粒向量$\ G(\ x\ )\ ,\ $进行前向计算 , 经过隐层计算和softmax后 , 输出粒向量$\ α\ =\ \{\ α_1\ ,\ α_2\ ,\ \dots\ ,\ α_l\ \}$
# 5. 计算输出模糊粒向量和标签模糊粒向量的损失函数$\ L(\ G(\ y\ )\ ,\ α\ )\ ,\ $称为**损失模糊粒**
# 6. 损失模糊粒反向传播以修改粒权向量
# 7. 转至$\ 4.\ $直至最大迭代或损失收敛
# 8. 输出$\ W\ 、\ b\ 、\ $参考样本集$\ S\ $

# %% [markdown]
# **粒残差网络分类算法**
# <BR>
# **输入** : 参考集$\ S\ =\ P_1\ ,\ P_2\ ,\ …\ ,\ P_k\ 、\ $粒权矩阵$\ W\ 、\ $粒阈值$\ b\ $
# **输出** : 样本$\ x\ $的类别
# 1. 测试样本$\ x\ $在参考集$\ S\ $下粒化为$\ G(\ x_i\ )\ =\ \left\{ g_1(\ x_i)\ ,\ g_2(\ x_i\ )\ ,\ \dots\ ,\ g_m(\ x_i\ ) \right\}\ $
# 2. 输入$\ G(\ x\ )$进行前向计算 , 隐层和softmax后 , 输出$\ l\ $个模糊粒$\ α_i\ $
# 3. 根据$\ α_i\ =\ \overset{k}{\underset{j=1}{\sum}}r_j\ $计算模糊粒$\ α_i\ $的大小$\ ,\ r_j\ $为$\ α_i\ $的粒核
# 4. softmax计算每种类别的可能性
# 5. 确定测试样本类别
